# %%
import pandas as pd

# %%
world_cup = pd.read_csv(r'womens-world-cup.csv')
world_cup
# Out:
#       id        squad  year  players   age  possesion  matches_played  starts  \
# 0      1    Argentina  2019       18  26.8       34.7               3      33
# 1      2    Australia  2019       18  25.4       61.3               4      44
# 2      3       Brazil  2019       18  29.7       51.5               4      44
# 3      4     Cameroon  2019       20  27.7       36.0               4      44
# 4      5       Canada  2019       16  27.0       63.0               4      44
# ..   ...          ...   ...      ...   ...        ...             ...     ...
# 131  132  New Zealand  1991       15  25.5        NaN               3      33
# 132  133      Nigeria  1991       17  18.2        NaN               3      33
# 133  134       Norway  1991       15  24.1        NaN               6      66
# 134  135       Sweden  1991       18  25.4        NaN               6      66
# 135  136          USA  1991       16  23.0        NaN               6      66
#
# ...

# %%
world_cup['continent'] = ''
world_cup
# Out:
#       id        squad  year  players   age  possesion  matches_played  starts  \
# 0      1    Argentina  2019       18  26.8       34.7               3      33
# 1      2    Australia  2019       18  25.4       61.3               4      44
# 2      3       Brazil  2019       18  29.7       51.5               4      44
# 3      4     Cameroon  2019       20  27.7       36.0               4      44
# 4      5       Canada  2019       16  27.0       63.0               4      44
# ..   ...          ...   ...      ...   ...        ...             ...     ...
# 131  132  New Zealand  1991       15  25.5        NaN               3      33
# 132  133      Nigeria  1991       17  18.2        NaN               3      33
# 133  134       Norway  1991       15  24.1        NaN               6      66
# 134  135       Sweden  1991       18  25.4        NaN               6      66
# 135  136          USA  1991       16  23.0        NaN               6      66
#
# ...

# %%
world_cup['squad'].value_counts()
# Out:
# Sweden            8
# Brazil            8
# USA               8
# Germany           8
# Japan             8
# Norway            8
# Nigeria           8
# Canada            7
# China PR          7
# Australia         7
# New Zealand       5
# England           5
# Korea DPR         4
# France            4
# Denmark           4
# Argentina         3
# Mexico            3
# Korea Rep         3
# Italy             3
# Ghana             3
# Thailand          2
# Colombia          2
# Netherlands       2
# Spain             2
# Russia            2
# Cameroon          2
# Equ. Guinea       1
# Switzerland       1
# Scotland          1
# Ecuador           1
# Côte d'Ivoire     1
# Costa Rica        1
# South Africa      1
# Jamaica           1
# Chile             1
# Chinese Taipei    1
# Name: squad, dtype: int64

# %% [markdown]
# # Hinzufügen der Konitnente

# %%
africa = world_cup.loc[(world_cup['squad'] == 'Nigeria') | (world_cup['squad'] == 'Cameroon') | 
                        (world_cup['squad'] == 'Ghana') |  
                        (world_cup['squad'] == 'Côte d\'Ivoire') | 
                        (world_cup['squad'] == 'Equ. Guinea') | 
                        (world_cup['squad'] == 'Jamaica') | 
                        (world_cup['squad'] == 'South Africa') ]
africa
# Out:
#       id          squad  year  players   age  possesion  matches_played  \
# 3      4       Cameroon  2019       20  27.7       36.0               4
# 11    12        Jamaica  2019       20  22.9       36.7               3
# 16    17        Nigeria  2019       20  25.7       34.8               4
# 19    20   South Africa  2019       19  27.5       38.0               3
# 26    27       Cameroon  2015       17  25.1       48.8               4
# 31    32  Côte d'Ivoire  2015       19  25.0       45.0               3
# 41    42        Nigeria  2015       17  24.6       48.3               3
# 53    54    Equ. Guinea  2011       15  26.1       40.7               3
# 60    61        Nigeria  2011       17  24.3       50.7               3
# 72    73          Ghana  2007       19  24.5       52.3               3
# 76    77        Nigeria  2007       15  23.6       51.0               3
# 87    88          Ghana  2003       15  25.4       47.7               3
# ...

# %%
africa = africa.assign(continent= 'Afrika')
africa
# Out:
#       id          squad  year  players   age  possesion  matches_played  \
# 3      4       Cameroon  2019       20  27.7       36.0               4
# 11    12        Jamaica  2019       20  22.9       36.7               3
# 16    17        Nigeria  2019       20  25.7       34.8               4
# 19    20   South Africa  2019       19  27.5       38.0               3
# 26    27       Cameroon  2015       17  25.1       48.8               4
# 31    32  Côte d'Ivoire  2015       19  25.0       45.0               3
# 41    42        Nigeria  2015       17  24.6       48.3               3
# 53    54    Equ. Guinea  2011       15  26.1       40.7               3
# 60    61        Nigeria  2011       17  24.3       50.7               3
# 72    73          Ghana  2007       19  24.5       52.3               3
# 76    77        Nigeria  2007       15  23.6       51.0               3
# 87    88          Ghana  2003       15  25.4       47.7               3
# ...

# %% [markdown]
# Europa

# %%
asien = world_cup.loc[(world_cup['squad'] == 'Japan') | 
                        (world_cup['squad'] == 'China PR') |  
                        (world_cup['squad'] == 'Chinese Taipei') | 
                        (world_cup['squad'] == 'Korea DPR') | 
                        (world_cup['squad'] == 'Korea Rep') | 
                        (world_cup['squad'] == 'Russia') | 
                        (world_cup['squad'] == 'Thailand') ]
asien
# Out:
#       id           squad  year  players   age  possesion  matches_played  \
# 6      7        China PR  2019       17  26.6       47.0               4
# 12    13           Japan  2019       17  24.8       53.8               4
# 13    14       Korea Rep  2019       19  26.9       52.0               3
# 22    23        Thailand  2019       18  27.8       30.0               3
# 28    29        China PR  2015       18  23.6       48.6               5
# 36    37           Japan  2015       23  27.9       55.1               7
# 37    38       Korea Rep  2015       19  26.1       43.8               4
# 46    47        Thailand  2015       17  25.7       40.0               3
# 56    57           Japan  2011       18  25.4       56.5               6
# 57    58       Korea DPR  2011       17  21.1       50.7               3
# 68    69        China PR  2007       18  24.9       47.3               4
# 73    74           Japan  2007       16  24.7       56.0               3
# ...

# %%
asien = asien.assign(continent= 'Asien')
asien
# Out:
#       id           squad  year  players   age  possesion  matches_played  \
# 6      7        China PR  2019       17  26.6       47.0               4
# 12    13           Japan  2019       17  24.8       53.8               4
# 13    14       Korea Rep  2019       19  26.9       52.0               3
# 22    23        Thailand  2019       18  27.8       30.0               3
# 28    29        China PR  2015       18  23.6       48.6               5
# 36    37           Japan  2015       23  27.9       55.1               7
# 37    38       Korea Rep  2015       19  26.1       43.8               4
# 46    47        Thailand  2015       17  25.7       40.0               3
# 56    57           Japan  2011       18  25.4       56.5               6
# 57    58       Korea DPR  2011       17  21.1       50.7               3
# 68    69        China PR  2007       18  24.9       47.3               4
# 73    74           Japan  2007       16  24.7       56.0               3
# ...

# %%
europe = world_cup.loc[(world_cup['squad'] == 'Germany') | 
                        (world_cup['squad'] == 'Sweden') |  
                        (world_cup['squad'] == 'Norway') |  
                        (world_cup['squad'] == 'England') |
                        (world_cup['squad'] == 'France') | 
                        (world_cup['squad'] == 'Denmark') | 
                        (world_cup['squad'] == 'Italy') | 
                        (world_cup['squad'] == 'Netherlands') | 
                        (world_cup['squad'] == 'Spain') | 
                        (world_cup['squad'] == 'Switzerland') | 
                        (world_cup['squad'] == 'Scotland') ]
europe
# Out:
#       id        squad  year  players   age  possesion  matches_played  starts  \
# 7      8      England  2019       22  27.8       60.4               7      77
# 8      9       France  2019       17  27.8       58.8               5      55
# 9     10      Germany  2019       19  25.5       57.2               5      55
# 10    11        Italy  2019       17  26.5       43.4               5      55
# 14    15  Netherlands  2019       16  26.1       57.1               7      77
# 17    18       Norway  2019       17  26.8       50.2               5      55
# 18    19     Scotland  2019       19  26.4       47.0               3      33
# 20    21        Spain  2019       19  25.2       62.5               4      44
# 21    22       Sweden  2019       20  28.5       48.4               7      77
# 33    34      England  2015       22  27.6       48.1               7      77
# 34    35       France  2015       19  27.3       53.6               5      55
# ...

# %%
europe = europe.assign(continent= 'Europa')
europe
# Out:
#       id        squad  year  players   age  possesion  matches_played  starts  \
# 7      8      England  2019       22  27.8       60.4               7      77
# 8      9       France  2019       17  27.8       58.8               5      55
# 9     10      Germany  2019       19  25.5       57.2               5      55
# 10    11        Italy  2019       17  26.5       43.4               5      55
# 14    15  Netherlands  2019       16  26.1       57.1               7      77
# 17    18       Norway  2019       17  26.8       50.2               5      55
# 18    19     Scotland  2019       19  26.4       47.0               3      33
# 20    21        Spain  2019       19  25.2       62.5               4      44
# 21    22       Sweden  2019       20  28.5       48.4               7      77
# 33    34      England  2015       22  27.6       48.1               7      77
# 34    35       France  2015       19  27.3       53.6               5      55
# ...

# %%
namerika = world_cup.loc[(world_cup['squad'] == 'USA') | 
                        (world_cup['squad'] == 'Canada') |  
                        (world_cup['squad'] == 'Mexico') | 
                        (world_cup['squad'] == 'Costa Rica') ]
namerika
# Out:
#       id       squad  year  players   age  possesion  matches_played  starts  \
# 4      5      Canada  2019       16  27.0       63.0               4      44
# 23    24         USA  2019       21  28.8       56.0               7      77
# 27    28      Canada  2015       18  27.2       55.0               5      55
# 30    31  Costa Rica  2015       15  25.0       42.3               3      33
# 38    39      Mexico  2015       17  24.3       52.3               3      33
# 47    48         USA  2015       20  28.4       52.9               7      77
# 50    51      Canada  2011       19  25.9       47.3               3      33
# 58    59      Mexico  2011       18  23.1       47.7               3      33
# 63    64         USA  2011       18  28.3       50.5               6      66
# 67    68      Canada  2007       18  23.8       39.3               3      33
# 79    80         USA  2007       18  26.7       46.5               6      66
# ...

# %%
namerika = namerika.assign(continent= 'Nordamerika')
namerika
# Out:
#       id       squad  year  players   age  possesion  matches_played  starts  \
# 4      5      Canada  2019       16  27.0       63.0               4      44
# 23    24         USA  2019       21  28.8       56.0               7      77
# 27    28      Canada  2015       18  27.2       55.0               5      55
# 30    31  Costa Rica  2015       15  25.0       42.3               3      33
# 38    39      Mexico  2015       17  24.3       52.3               3      33
# 47    48         USA  2015       20  28.4       52.9               7      77
# 50    51      Canada  2011       19  25.9       47.3               3      33
# 58    59      Mexico  2011       18  23.1       47.7               3      33
# 63    64         USA  2011       18  28.3       50.5               6      66
# 67    68      Canada  2007       18  23.8       39.3               3      33
# 79    80         USA  2007       18  26.7       46.5               6      66
# ...

# %%
oceanien = world_cup.loc[(world_cup['squad'] == 'Australien') |  
                        (world_cup['squad'] == 'New Zealand') ]

# %%
oceanien = oceanien.assign(continent= 'Ozeanien')
oceanien
# Out:
#       id        squad  year  players   age  possesion  matches_played  starts  \
# 15    16  New Zealand  2019       17  27.6       39.3               3      33
# 40    41  New Zealand  2015       15  24.9       46.7               3      33
# 59    60  New Zealand  2011       16  24.4       45.7               3      33
# 75    76  New Zealand  2007       18  24.5       39.7               3      33
# 131  132  New Zealand  1991       15  25.5        NaN               3      33
#
#      min_playing_time  minutes_played_90s  ...  penalty_kicks_made  \
# 15                270                 3.0  ...                   0
# 40                270                 3.0  ...                   0
# 59                270                 3.0  ...                   0
# 75                270                 3.0  ...                   0
# 131               240                 2.7  ...                   0
#
#      penalty_kicks_attempted  yellow_cards  red_cards  goals_per_90  \
# ...

# %%
samerika = world_cup.loc[(world_cup['squad'] == 'Argentinien') | 
                        (world_cup['squad'] == 'Colombia') |
                        (world_cup['squad'] == 'Brazil') |  
                        (world_cup['squad'] == 'Chile') | 
                        (world_cup['squad'] == 'Ecuador') ]

# %%
samerika = samerika.assign(continent= 'Südamerika')
samerika
# Out:
#       id     squad  year  players   age  possesion  matches_played  starts  \
# 2      3    Brazil  2019       18  29.7       51.5               4      44
# 5      6     Chile  2019       18  26.8       42.0               3      33
# 25    26    Brazil  2015       20  27.4       59.0               4      44
# 29    30  Colombia  2015       18  24.3       44.3               4      44
# 32    33   Ecuador  2015       19  23.4       38.7               3      33
# 49    50    Brazil  2011       16  27.0       53.3               4      44
# 51    52  Colombia  2011       17  22.4       49.3               3      33
# 66    67    Brazil  2007       16  25.7       61.3               6      66
# 82    83    Brazil  2003       16  22.4       55.0               4      44
# 97    98    Brazil  1999       15  25.0        NaN               6      66
# 113  114    Brazil  1995       16  27.9        NaN               3      33
# ...

# %%
frames = [africa, asien, europe, samerika, namerika, oceanien]


result = pd.concat(frames)
result
# Out:
#       id         squad  year  players   age  possesion  matches_played  \
# 3      4      Cameroon  2019       20  27.7       36.0               4
# 11    12       Jamaica  2019       20  22.9       36.7               3
# 16    17       Nigeria  2019       20  25.7       34.8               4
# 19    20  South Africa  2019       19  27.5       38.0               3
# 26    27      Cameroon  2015       17  25.1       48.8               4
# ..   ...           ...   ...      ...   ...        ...             ...
# 15    16   New Zealand  2019       17  27.6       39.3               3
# 40    41   New Zealand  2015       15  24.9       46.7               3
# 59    60   New Zealand  2011       16  24.4       45.7               3
# 75    76   New Zealand  2007       18  24.5       39.7               3
# 131  132   New Zealand  1991       15  25.5        NaN               3
#
#      starts  min_playing_time  minutes_played_90s  ...  penalty_kicks_made  \
# ...

# %%
result.to_csv('cup_continent.csv')
